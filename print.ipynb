# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunali13858/Student_Management_System/blob/main/print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("I am Mrunali","my age is 21")
# Out:
# I am Mrunali my age is 21

# %%
print(13+19)
# Out:
# 32

# %%
print(13-7)
# Out:
# 6

# %%
print(12*2)
# Out:
# 24

# %%
print(20/2)
# Out:
# 10.0
