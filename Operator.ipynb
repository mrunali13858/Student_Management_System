# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunali13858/Student_Management_System/blob/main/Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Types of Operators:-
#
#
# An operator is a symbol that performs a certain operation between operands
#
#
# .Arithmetic Operators(+,-,*,/,%.**)
#
#
#
# .Relational / Comparison Operators(==,!=,<,>,>=,<=)
#
#
#
# .Assignment Operators(=,+=,-=,/=,%=,**=)
#
#
#
# .Logical Operators(not,and,or)

# %%
#Arithmetic operator
a=5
b=2

sum=a+b

print(sum)
# Out:
# 7

# %%
a=5
b=2


print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b) #remainder
print(a**b) #a^b
# Out:
# 7
# 3
# 10
# 2.5
# 1
# 25

# %%
#ralational Operators
a=50
b=20

print(a==b)
print(a!=b)
print(a>=b)
print(a>b)
print(a<=b)
print(a<b)
# Out:
# False
# True
# True
# True
# False
# False

# %%
#Assignment Operator
num=10
num=num +10 #10+10=>20
print(num)
# Out:
# 20

# %%
num=10
num += 10
print("num:",num )
# Out:
# num: 20

# %%
num=10
num -= 10
print("num:",num )
# Out:
# num: 0

# %%
num=10
num *= 10
print("num:",num )
# Out:
# num: 100

# %%
num=10
num /= 10
print("num:",num )
# Out:
# num: 1.0

# %%
num=10
num %= 10
print("num:",num )
# Out:
# num: 0

# %%
num=10
num **= 10
print("num:",num )
# Out:
# num: 10000000000

# %%
#logical Operators
print(not False)
print(not True)
# Out:
# True
# False

# %%
a=50
b= 30
print(not False)
print(not(a>b))
# Out:
# True
# False

# %%
val1=True
val2=True
print("and operator:",val1 and val2)
# Out:
# and operator: True

# %%
val1=True
val2=False
print("and operator:",val1 and val2)
# Out:
# and operator: False

# %%
val1=True
val2=False
print("Or operator:",val1 or val2)
# Out:
# Or operator: True
