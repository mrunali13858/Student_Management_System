# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunali13858/Student_Management_System/blob/main/type_casting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#type casting

a = int("2")
b = 4.25
print(type(a))
print(a + b)
# Out:
# <class 'int'>
# 6.25

# %%
a = float("2")
b = 4.25
print(type(a))
print(a + b)
# Out:
# <class 'float'>
# 6.25
