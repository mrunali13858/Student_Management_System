# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunali13858/Student_Management_System/blob/main/variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# variable:- A variable is a name given to a memory location in a program.
# 1) (=)assignment operator

# %%
name="Mrunali" #string
age=21         # int
price=25.99   # decimal #float

print("My Name is:",name)
print("My Age is:",age)
print("My Price is:",price)
# Out:
# My Name is: Mrunali
# My Age is: 21
# My Price is: 25.99

# %%
name="Mrunali"
age=21
price=25.99

age2=age
print(age2)
# Out:
# 21

# %% [markdown]
# Rules for Identifiers:-
#                       1. Identifiers can be combination of uppercase and lowercase letters,digits pr an underscore(_).
#                       so myVariable,Variable_1,Variable_for_print all are valid python identifiers.
#
#                       2. An identifier can not start with digit. So while Variable1 is valid,1variable is not valid.
#
#                       3. We can't use special symbols like !,#,@,%,$ etc in our identifier.
#
#                       4. Identifier can be of any length.

# %%
print(type(name))
print(type(age))
print(type(price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Data Types:-
#           1. Integers, Ex=1,34,-50,-3
#           2. String, Ex= "mrunali",'mrunali','''mrunali'''
#           3. Float, Ex=50.60.3.5
#           4. Boolean,Ex= True,False
#           5. None,Ex= a=None

# %%
age=23
old=True
a=None

print(type(old))
print(type(a))
# Out:
# <class 'bool'>
# <class 'NoneType'>
