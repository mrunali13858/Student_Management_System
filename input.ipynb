# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunali13858/Student_Management_System/blob/main/input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Input():- statement is used to accept values (using Keyboard)from user
#
# input() #result for input() is always a str
#
#
# int(input()) #int
#
#
# float(input()) # float

# %%
input("Enter your name:")
# Out:
# Enter your name:mrunali
# 'mrunali'

# %%
name=input("enter your name:")
print("Welcome",name)
# Out:
# enter your name:shradhha
# Welcome shradhha

# %%
val=int(input("Enter some values:"))
print(type(val),val)
# Out:
# Enter some values:21
# <class 'int'> 21

# %%
name=input("enter your name:")
age=int(input("enter your age:"))
marks=float(input("enter your marks: "))

print("Welcome",name)
print("age",age)
print("marks",marks)
# Out:
# enter your name:shradhha
# enter your age:22
# enter your marks: 90
# Welcome shradhha
# age 22
# marks 90.0
