# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunali13858/Student_Management_System/blob/main/type_conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#type conversion
a = 2
b = 4.25

sum = a + b # 2.0 + 4.25=> 6.25
print(sum)
# Out:
# 6.25
